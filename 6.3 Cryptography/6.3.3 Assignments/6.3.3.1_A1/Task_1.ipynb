# %%
file = open("./ciphertext_test_73.txt")
file = file.read()
frequency = {}

for char in file:
    if char in list(frequency.keys()):
        frequency[char]+=1
    else:
        frequency[char] = 1

for key in frequency.keys():
    frequency[key] = round(frequency[key]/len(file),5)

frequency = dict(sorted(frequency.items(),key=lambda item: item[1],reverse=True))
for item in frequency.items():
    print("'"+item[0]+"' :",item[1])

print(len(frequency))

normalized_frequency_data = {
    'a': 0.0752766,
    'e': 0.070925,
    'o': 0.0517,
    'r': 0.0496032,
    'i': 0.0469732,
    's': 0.0461079,
    'n': 0.0456899,
    '1': 0.0435053,
    't': 0.0387388,
    'l': 0.0377728,
    '2': 0.0312312,
    'm': 0.0299913,
    'd': 0.0276401,
    '0': 0.0274381,
    'c': 0.0257276,
    'p': 0.0245578,
    '3': 0.0243339,
    'h': 0.0241319,
    'b': 0.0229145,
    'u': 0.0210191,
    'k': 0.0196828,
    '4': 0.0194265,
    '5': 0.0188577,
    'g': 0.0185331,
    '9': 0.0179558,
    '6': 0.0175647,
    '8': 0.0166225,
    '7': 0.01621,
    'y': 0.0152483,
    'f': 0.012476,
    'w': 0.0124492,
    'j': 0.00836677,
    'v': 0.00833626,
    'z': 0.00632558,
    'x': 0.00573305,
    'q': 0.00346119,
    'A': 0.00130466,
    'S': 0.00108132,
    'E': 0.000970865,
    'R': 0.0008476,
    'B': 0.000806715,
    'T': 0.000801223,
    'M': 0.000782306,
    'L': 0.000775594,
    'N': 0.000748134,
    'P': 0.00073715,
    'O': 0.000729217,
    'I': 0.00070908,
    'D': 0.000698096,
    'C': 0.000660872,
    'H': 0.000544319,
    'G': 0.000497332,
    'K': 0.000460719,
    'F': 0.000417393,
    'J': 0.000363083,
    'U': 0.000350268,
    'W': 0.000320367,
    '.': 0.000316706,
    '!': 0.000306942,
    'Y': 0.000255073,
    '*': 0.000241648,
    '@': 0.000238597,
    'V': 0.000235546,
    '-': 0.000197712,
    'Z': 0.000170252,
    'Q': 0.000147064,
    'X': 0.000142182,
    '_': 0.000122655,
    '$': 0.0000970255,
    '#': 0.0000854313,
    ',': 0.0000323418,
    '/': 0.0000311214,
    '+': 0.0000231885,
    '?': 0.0000207476,
    ';': 0.0000207476,
    '^': 0.0000195272,
    ' ': 0.0000189169,
    '%': 0.0000170863,
    '~': 0.0000152556,
    '=': 0.0000140351,
    '&': 0.0000134249,
    '`': 0.0000115942,
    '\\': 0.0000115942,
    ')': 0.0000115942,
    ']': 0.000010984,
    '[': 0.000010984,
    ':': 0.00000549201,
    '<': 0.00000427156,
    '(': 0.00000427156,
    'æ': 0.00000183067,
    '>': 0.00000183067,
    '"': 0.00000183067,
    'ü': 0.00000122045,
    '|': 0.00000122045,
    '{': 0.00000122045,
    "'": 0.00000122045,
    'ö': 6.10223e-06,
    'ä': 6.10223e-06,
    '}': 6.10223e-06
}
# Out:
# '*' : 0.25417
# 'h' : 0.09098
# '\' : 0.05497
# '{' : 0.05139
# 'G' : 0.04882
# '~' : 0.04216
# 'c' : 0.04042
# 'l' : 0.03984
# '0' : 0.03923
# ''' : 0.0291
# '
# ' : 0.02322
# 'a' : 0.0199
# 'r' : 0.01958
# 'J' : 0.01752
# '.' : 0.01438
# 'w' : 0.01389
# 'W' : 0.01375
# '3' : 0.01368
# '7' : 0.01264
# 'K' : 0.01152
# 'O' : 0.00875
# ')' : 0.00718
# '#' : 0.00646
# 't' : 0.00624
# 'x' : 0.0061
# '[' : 0.00606
# 'F' : 0.00586
# 's' : 0.00569
# '5' : 0.00554
# '}' : 0.00552
# 'i' : 0.00546
# 'y' : 0.00485
# 'k' : 0.0048
# 'j' : 0.00465
# ']' : 0.00454
# 'm' : 0.00379
# 'T' : 0.00364
# '`' : 0.0034
# '|' : 0.0033
# 'M' : 0.003
# ' ' : 0.00289
# 'I' : 0.0028
# 'E' : 0.00246
# 'A' : 0.00246
# 'L' : 0.00246
# 'p' : 0.00223
# '4' : 0.00214
# '9' : 0.00174
# 'd' : 0.00171
# ';' : 0.00151
# ':' : 0.00147
# '!' : 0.00147
# '?' : 0.00135
# '_' : 0.00133
# '$' : 0.00096
# 'D' : 0.00096
# 'H' : 0.00096
# '=' : 0.00092
# '1' : 0.0009
# 'S' : 0.00089
# 'Q' : 0.00087
# 'g' : 0.00081
# 'Y' : 0.0008
# ...

# %%
del normalized_frequency_data[" "]
del frequency["*"]

# %%
replace = {
    "E":"N",
    "h":"e",
    "{":"t",
    "}":"w",
    "c":"o",
    "~":"r",
    "9":"k",
    "R":"W",
    "G":"i",
    "l":"n",
    "#":"g",
    ">":"G",
    "W":"u",
    ".":"p",
    "`":"R",
    "T":"q",
    "3":"f",
    "|":"C",
    "K":"m",
    "A":":",
    "0":"a",
    "j":"y",
    "O":"S",
    "w":"c",
    "J":".",
    "r":"d",
    ")":"T",
    "u":"J",
    "x":"b",
    "'":"h",
    "y":"I",
    "i":"A",
    "a":"l",
    "k":"2",
    "]":"0",
    "4":"D",
    "[":"v",
    "L":"4",
    "_":"8",
    "$":"5",
    "I":"P",
    ":":"(",
    "!":")",
    "5":",",
    "+":'"',
    "d":"O",
    " ":"1",
    "^":"z",
    "t":"x",
    "7":"-",
    "g":"V",
    "s":"E",
    "m":"U",
    "n":"&",
    "Y":"[",
    "o":"]",
    ";":"F",
    "1":"B",
    "H":"6",
    "=":"7",
    "?":"3",
    "p":"'",
    "S":"9",
    ",":"+",
    "F":"|",
    "M":"M",
    "D":"H",
    "Q":"L",
    "C":"Y",
    "-":";",
    "U":"/",
    "@":">",
    "Z":"<",
    "N":"=",
    "8":"K",
    "z":"@",
    "P":"j",
    "B":"x",
    "e":"e",
    "X":"*",
    "b":"%",
    "<":"?",
    "/":"Z"
}

decipher = ""
for i in range(len(file)):
    if file[i] == "*":
        decipher+=" "
    elif file[i] in replace.keys():
        decipher+=replace[file[i]]
    else:
        decipher+=file[i]
# \ -> s

# %%
new_file = open("./decipher.txt","w")
new_file.write(decipher)
# Out:
# 65365

# %%
len(replace)
# Out:
# 83

# %%
for key in frequency.keys():
    if key not in replace.keys():
        print(key)
# Out:
# \

# %%
len(frequency)
# Out:
# 84
